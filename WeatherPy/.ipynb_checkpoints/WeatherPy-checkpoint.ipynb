# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 645

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
# Getting my query_url using the imperial units, since temperatura is det in fahrenheit unit, checked in the cvs file.

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
city_name = []
country = []
cloudiness = []
country = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []


# Loop through each city
for city in cities:
    
    # Create search query, make request and store in json
    #query = url + cities
    #response_jason = requests.get(query)
    #response_json = response.json()
    
    # Try to grab the info abailable in weather API
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        print(f"City close to the equador: {city}")
    
        time.sleep(60)
    # Handle exceptions for a character that is not available in the Star Wars API
    
    except KeyError:
        # Append null values
        print("City not close to the equador: {city}")
# Out:
# City close to the equador: berdigestyakh
# City close to the equador: guerrero negro
# City close to the equador: san francisco
# City close to the equador: dewas
# City close to the equador: ust-nera
# City not close to the equador: {city}
# City close to the equador: kapaa
# City close to the equador: fort nelson
# City close to the equador: busselton
# City close to the equador: castro
# City close to the equador: punta arenas
# City close to the equador: normandin
# City close to the equador: fairbanks
# City close to the equador: tasiilaq
# City not close to the equador: {city}
# City close to the equador: rundu
# City close to the equador: sinnamary
# City close to the equador: ushuaia
# City close to the equador: ipswich
# City close to the equador: hermanus
# City not close to the equador: {city}
# City close to the equador: cape town
# City close to the equador: ternate
# City not close to the equador: {city}
# City close to the equador: albany
# City close to the equador: saskylakh
# City close to the equador: avarua
# City close to the equador: cherskiy
# City not close to the equador: {city}
# City close to the equador: nome
# City close to the equador: mataura
# City close to the equador: tolaga bay
# City close to the equador: wanning
# City not close to the equador: {city}
# City close to the equador: codrington
# City close to the equador: pidhorodna
# City close to the equador: provideniya
# City close to the equador: thompson
# City close to the equador: urucui
# City close to the equador: ponta do sol
# City close to the equador: ipameri
# City close to the equador: san quintin
# City close to the equador: richards bay
# City close to the equador: tezu
# City close to the equador: kushima
# City close to the equador: hofn
# City close to the equador: zapolyarnyy
# City not close to the equador: {city}
# City close to the equador: juelsminde
# City close to the equador: martapura
# City close to the equador: tuktoyaktuk
# City close to the equador: severo-kurilsk
# City close to the equador: upernavik
# City close to the equador: chuy
# City close to the equador: coquimbo
# City close to the equador: igarka
# City close to the equador: fare
# City close to the equador: quatre cocos
# City close to the equador: porto velho
# City not close to the equador: {city}
# City close to the equador: la peca
# City close to the equador: nikolskoye
# City close to the equador: evensk
# City close to the equador: bullhead city
# City close to the equador: port alfred
# City close to the equador: rikitea
# City close to the equador: hilo
# City close to the equador: flin flon
# City close to the equador: thinadhoo
# City close to the equador: linxia
# City close to the equador: bethel
# City close to the equador: hithadhoo
# City close to the equador: sitka
# City close to the equador: meulaboh
# City close to the equador: faanui
# City close to the equador: hun
# City close to the equador: golden
# City close to the equador: morehead
# City not close to the equador: {city}
# City close to the equador: nanchang
# City close to the equador: paamiut
# City close to the equador: cairns
# City close to the equador: saint-philippe
# City close to the equador: rincon
# City close to the equador: bilma
# City close to the equador: new norfolk
# City close to the equador: seoul
# City close to the equador: topeka
# City close to the equador: dikson
# City close to the equador: leningradskiy
# City close to the equador: qaanaaq
# City close to the equador: poum
# City close to the equador: geraldton
# City close to the equador: siocon
# City close to the equador: treinta y tres
# City close to the equador: ketchikan
# City close to the equador: bluff
# City close to the equador: bredasdorp
# City close to the equador: launceston
# City close to the equador: pevek
# City close to the equador: carballo
# City close to the equador: butaritari
# City close to the equador: georgetown
# City close to the equador: tilichiki
# City close to the equador: desbiens
# City close to the equador: vaini
# City close to the equador: tuatapere
# City close to the equador: tommot
# City close to the equador: wanlaweyn
# City close to the equador: broken hill
# City close to the equador: college
# City close to the equador: sola
# City close to the equador: barrow
# City close to the equador: trincomalee
# City close to the equador: xiongzhou
# City close to the equador: adrar
# City close to the equador: khash
# City close to the equador: carnarvon
# City close to the equador: saldanha
# City close to the equador: vestmannaeyjar
# City close to the equador: porto belo
# City close to the equador: east london
# City close to the equador: ancud
# City close to the equador: qianan
# City close to the equador: jamestown
# City close to the equador: talnakh
# City close to the equador: bathsheba
# City close to the equador: gizo
# City close to the equador: terenos
# City not close to the equador: {city}
# City close to the equador: harnosand
# City not close to the equador: {city}
# City close to the equador: karratha
# City close to the equador: pacific grove
# City close to the equador: elat
# City close to the equador: ribeira grande
# City close to the equador: hobart
# City close to the equador: saint george
# City close to the equador: klaksvik
# City not close to the equador: {city}
# City close to the equador: esperance
# City close to the equador: haines junction
# City close to the equador: surt
# City close to the equador: ostrovnoy
# City close to the equador: puerto escondido
# City close to the equador: kavaratti
# City close to the equador: loding
# City close to the equador: salym
# City close to the equador: khatanga
# City close to the equador: ixtapa
# City close to the equador: yellowknife
# City close to the equador: wasilla
# City close to the equador: comodoro rivadavia
# City close to the equador: lere
# City close to the equador: cabo san lucas
# City close to the equador: whitianga
# City not close to the equador: {city}
# City close to the equador: ushtobe
# City close to the equador: serenje
# City close to the equador: remanso
# City close to the equador: vardo
# City not close to the equador: {city}
# City close to the equador: kavieng
# City close to the equador: deputatskiy
# City close to the equador: samarai
# City not close to the equador: {city}
# City close to the equador: sisimiut
# City close to the equador: sorong
# City close to the equador: wattegama
# City close to the equador: panguna
# City close to the equador: los llanos de aridane
# City close to the equador: sosua
# City close to the equador: magdagachi
# City close to the equador: bjornevatn
# City close to the equador: aswan
# City close to the equador: buraydah
# City close to the equador: santa rosa
# City close to the equador: khandyga
# City close to the equador: cabadiangan
# City close to the equador: beaverlodge
# City close to the equador: san jose
# City close to the equador: cobija
# City close to the equador: barcelos
# City close to the equador: vila velha
# City close to the equador: narsaq
# City close to the equador: ojinaga
# City close to the equador: gayny
# City close to the equador: hovd
# City close to the equador: taree
# City close to the equador: lae
# City close to the equador: san luis
# City close to the equador: banda aceh
# City close to the equador: inowroclaw
# City close to the equador: bandarbeyla
# City close to the equador: murakami
# City close to the equador: kieta
# City close to the equador: beira
# City not close to the equador: {city}
# City close to the equador: cacule
# City close to the equador: puerto ayora
# City not close to the equador: {city}
# City close to the equador: praya
# City close to the equador: meadow lake
# City close to the equador: san vicente
# City close to the equador: bambous virieux
# City close to the equador: turukhansk
# City not close to the equador: {city}
# City close to the equador: san javier
# City not close to the equador: {city}
# City close to the equador: deer lake
# City close to the equador: ilulissat
# City not close to the equador: {city}
# City close to the equador: port lincoln
# City close to the equador: kruisfontein
# City close to the equador: coahuayana
# City close to the equador: usinsk
# City close to the equador: port-gentil
# City close to the equador: kashan
# City close to the equador: narasannapeta
# City not close to the equador: {city}
# City close to the equador: biak
# City close to the equador: corowa
# City close to the equador: panaba
# City close to the equador: mbandaka
# City close to the equador: natal
# City close to the equador: zalantun
# City close to the equador: yulara
# City close to the equador: airai
# City close to the equador: bassar
# City close to the equador: port elizabeth
# City close to the equador: araguacu
# City close to the equador: atuona
# City close to the equador: portree
# City close to the equador: sao joao da barra
# City close to the equador: lagoa
# City close to the equador: vanimo
# City close to the equador: westport
# City close to the equador: shimoda
# City close to the equador: nobres
# City close to the equador: mahebourg
# City close to the equador: marabba
# City close to the equador: cidreira
# City close to the equador: sinop
# City close to the equador: sioux lookout
# City close to the equador: hualmay
# City close to the equador: muriwai beach
# City close to the equador: monki
# City close to the equador: sobolevo
# City close to the equador: atar
# City close to the equador: zambezi
# City close to the equador: chapais
# City close to the equador: bengkulu
# City close to the equador: makakilo city
# City close to the equador: puerto ayacucho
# City close to the equador: rivadavia
# City close to the equador: sao gabriel da cachoeira
# City close to the equador: lorengau
# City close to the equador: college station
# City close to the equador: alofi
# City close to the equador: port blair
# City close to the equador: itoman
# City close to the equador: santo antonio do monte
# City close to the equador: kawalu
# City close to the equador: rondonopolis
# City close to the equador: pochutla
# City close to the equador: zhigansk
# City close to the equador: elko
# City close to the equador: anadyr
# City close to the equador: iqaluit
# City close to the equador: opuwo
# City close to the equador: ankara
# City close to the equador: half moon bay
# City close to the equador: bayshore gardens
# City not close to the equador: {city}
# City close to the equador: kahului
# City close to the equador: karasuk
# City close to the equador: mount gambier
# City close to the equador: benghazi
# City close to the equador: antofagasta
# City close to the equador: neka
# City not close to the equador: {city}
# City close to the equador: mar del plata
# City close to the equador: udomlya
# City close to the equador: shimanovsk
# City close to the equador: porto novo
# City close to the equador: ahuimanu
# City close to the equador: saint andrews
# City close to the equador: constitucion
# City close to the equador: tortoli
# City close to the equador: tancanhuitz
# City close to the equador: nuevo progreso
# City close to the equador: lebu
# City close to the equador: tiksi
# City not close to the equador: {city}
# City close to the equador: lavrentiya
# City close to the equador: gillette
# City close to the equador: mayor pablo lagerenza
# City close to the equador: ilo
# City close to the equador: olinda
# City close to the equador: tromso
# City close to the equador: aksu
# City close to the equador: burns lake
# City close to the equador: clyde river
# City close to the equador: ayan
# City close to the equador: pokhara
# City close to the equador: hede
# City close to the equador: bodden town
# City close to the equador: karwar
# City close to the equador: cayenne
# City close to the equador: laguna
# City not close to the equador: {city}
# City close to the equador: jinxiang
# City close to the equador: kodiak
# City close to the equador: rafaela
# City close to the equador: arman
# City close to the equador: vila franca do campo
# City close to the equador: erzin
# City close to the equador: komsomolskiy
# City close to the equador: gaillac
# City close to the equador: nouadhibou
# City close to the equador: tateyama
# City not close to the equador: {city}
# City close to the equador: terra santa
# City close to the equador: sovetsk
# City not close to the equador: {city}
# City close to the equador: torbay
# City close to the equador: east moline
# City close to the equador: kununurra
# City close to the equador: ulkan
# City close to the equador: lata
# City close to the equador: great yarmouth
# City close to the equador: innisfail
# City close to the equador: farah
# City close to the equador: tutoia
# City close to the equador: souris
# City close to the equador: oranjemund
# City close to the equador: hirara
# City close to the equador: magalia
# City close to the equador: saravan
# City close to the equador: oksfjord
# City close to the equador: sayyan
# City close to the equador: trento
# City close to the equador: point pleasant
# City close to the equador: gimli
# City close to the equador: bacolod
# City close to the equador: kaitangata
# City close to the equador: chokurdakh
# City close to the equador: mayumba
# City close to the equador: portland
# City close to the equador: nanortalik
# City close to the equador: khani
# City close to the equador: galle
# City close to the equador: baykit
# City close to the equador: morondava
# City close to the equador: lardos
# City close to the equador: jiuquan
# City close to the equador: dragoesti
# City close to the equador: lazaro cardenas
# City not close to the equador: {city}
# City close to the equador: aktau
# City close to the equador: atasu
# City close to the equador: beyneu
# City close to the equador: dedovichi
# City close to the equador: ghedi
# City close to the equador: candido mendes
# City close to the equador: pasighat
# City not close to the equador: {city}
# City close to the equador: jertih
# City close to the equador: husavik
# City close to the equador: appleton
# City close to the equador: beringovskiy
# City close to the equador: port hardy
# City close to the equador: vanino
# City close to the equador: mugur-aksy
# City close to the equador: ranong
# City close to the equador: aklavik
# City close to the equador: sao filipe
# City close to the equador: guozhen
# City close to the equador: yichang
# City close to the equador: usakos
# City close to the equador: estelle
# City close to the equador: rapid valley
# City close to the equador: hami
# City not close to the equador: {city}
# City close to the equador: darhan
# City close to the equador: gazli
# City close to the equador: manaure
# City close to the equador: kabare
# City close to the equador: souillac
# City close to the equador: shiojiri
# City close to the equador: okato
# City close to the equador: nhulunbuy
# City not close to the equador: {city}
# City close to the equador: senanga
# City close to the equador: rio gallegos
# City close to the equador: san patricio
# City close to the equador: isangel
# City close to the equador: roald
# City close to the equador: taga
# City close to the equador: uppsala
# City close to the equador: huizhou
# City close to the equador: alanya
# City close to the equador: ndioum
# City close to the equador: palmer
# City close to the equador: batagay-alyta
# City close to the equador: umea
# City close to the equador: mahon
# City close to the equador: caravelas
# City close to the equador: gharghoda
# City close to the equador: sarai
# City close to the equador: gidam
# City close to the equador: yeppoon
# City close to the equador: grindavik
# City close to the equador: longyearbyen
# City close to the equador: nantucket
# City not close to the equador: {city}
# City close to the equador: dunedin
# City close to the equador: dudinka
# City close to the equador: praia
# City close to the equador: chunskiy
# City close to the equador: lodja
# City close to the equador: cicero dantas
# City close to the equador: axim
# City close to the equador: la ciotat
# City close to the equador: aktas
# City close to the equador: vila do maio
# City close to the equador: san carlos de bariloche
# City close to the equador: peace river
# City close to the equador: funadhoo
# City close to the equador: kajaani
# City close to the equador: berezniki
# City close to the equador: bunbury
# City close to the equador: srednekolymsk
# City close to the equador: hobyo
# City close to the equador: pimentel
# City close to the equador: sakakah
# City close to the equador: nyanza
# City not close to the equador: {city}
# City close to the equador: pauini
# City close to the equador: micheweni
# City close to the equador: ola
# City close to the equador: boende
# City close to the equador: moose factory
# City close to the equador: arraial do cabo
# City close to the equador: kabompo
# City close to the equador: shyryayeve
# City close to the equador: itarema
# City close to the equador: finspang
# City close to the equador: ambilobe
# City close to the equador: kasempa
# City close to the equador: krasnoselkup
# City close to the equador: tiznit
# City close to the equador: brae
# City close to the equador: ajdabiya
# City close to the equador: cervo
# City close to the equador: victoria point
# City close to the equador: binan
# City close to the equador: nanlong
# City not close to the equador: {city}
# City close to the equador: thayetmyo
# City close to the equador: kyren
# City close to the equador: flinders
# City close to the equador: mangan
# City close to the equador: muros
# City close to the equador: qarqin
# City close to the equador: oistins
# City not close to the equador: {city}
# City close to the equador: qui nhon
# City not close to the equador: {city}
# City close to the equador: talcahuano
# City close to the equador: puerto carreno
# City close to the equador: constantine
# City not close to the equador: {city}
# City close to the equador: saquena
# City close to the equador: berlevag
# City close to the equador: sibu
# City close to the equador: izumo
# City close to the equador: praia da vitoria
# City close to the equador: angoram
# City not close to the equador: {city}
# City close to the equador: mount isa
# City close to the equador: nisia floresta
# City close to the equador: bridgetown
# City close to the equador: trelleborg
# City close to the equador: obigarm
# City not close to the equador: {city}
# City close to the equador: marevo
# City close to the equador: riyadh
# City close to the equador: nelson bay
# City close to the equador: kihei
# City close to the equador: randolph
# City close to the equador: labuhan
# City close to the equador: nakambala
# City close to the equador: west lorne
# City close to the equador: padang
# City close to the equador: coihaique
# City close to the equador: lourdes
# City close to the equador: savelugu
# City close to the equador: luorong
# City not close to the equador: {city}
# City close to the equador: araouane
# City close to the equador: pobe
# City close to the equador: impfondo
# City close to the equador: toumodi
# City close to the equador: liseleje
# City close to the equador: gdansk
# City close to the equador: lososina
# City close to the equador: mocuba
# City close to the equador: bitung
# City close to the equador: kirakira
# City close to the equador: tondano
# City close to the equador: namibe
# City close to the equador: alto longa
# City close to the equador: lompoc
# City close to the equador: la ronge
# City close to the equador: fortuna
# City close to the equador: juneau
# City close to the equador: matata
# City close to the equador: ballina
# City close to the equador: acapulco
# City close to the equador: mitsamiouli
# City close to the equador: ratnapura
# City close to the equador: dingle
# City close to the equador: pingliang
# City close to the equador: foso
# City not close to the equador: {city}
# City close to the equador: cay
# City close to the equador: homer
# City close to the equador: bowen
# City close to the equador: mingyue
# City close to the equador: kamenka
# City close to the equador: omboue
# City close to the equador: nokaneng
# City close to the equador: choma
# City close to the equador: payson
# City close to the equador: maceio
# City close to the equador: nzerekore
# City close to the equador: maragogi
# City close to the equador: katsuura
# City close to the equador: buala
# City close to the equador: eureka
# City close to the equador: sorland
# City close to the equador: roma
# City close to the equador: coos bay
# City close to the equador: victoria
# City close to the equador: rocha
# City close to the equador: calama
# City close to the equador: salamiyah
# City close to the equador: palauig
# City close to the equador: saint-pierre
# City close to the equador: port harcourt
# City not close to the equador: {city}
# City close to the equador: xining
# City close to the equador: mlonggo
# City close to the equador: san matias
# City close to the equador: huaraz
# City close to the equador: lima
# City close to the equador: kurdzhinovo
# City close to the equador: kaili
# City close to the equador: nsanje
# City close to the equador: vostok
# City not close to the equador: {city}
# City close to the equador: aykhal
# City close to the equador: raudeberg
# City close to the equador: parfino
# City close to the equador: khotynets
# City close to the equador: severomuysk
# City close to the equador: guhagar
# City close to the equador: basco
# City close to the equador: san antonio
# City close to the equador: nizhnetroitskiy
# City close to the equador: qaqortoq
# City close to the equador: askiz
# City close to the equador: sweetwater
# City close to the equador: bima
# City close to the equador: salinopolis
# City close to the equador: chumikan
# City close to the equador: ahipara
# City close to the equador: otradnoye
# City close to the equador: diego de almagro
# City close to the equador: asau
# City close to the equador: udachnyy
# City close to the equador: kahramanmaras
# City close to the equador: galion
# City not close to the equador: {city}
# City close to the equador: cimislia
# City close to the equador: tobermory
# City close to the equador: banjar
# City not close to the equador: {city}
# City close to the equador: hasaki
# City close to the equador: kokopo
# City close to the equador: pitsunda
# City close to the equador: dickinson
# City not close to the equador: {city}
# City close to the equador: margate
# City close to the equador: kushchevskaya
# City close to the equador: muisne
# City not close to the equador: {city}
# City close to the equador: naze
# City close to the equador: mindelo
# City close to the equador: ucluelet
# City close to the equador: byron bay
# City close to the equador: mandalgovi
# City close to the equador: farafangana
# City close to the equador: sayat
# City close to the equador: oranzherei
# City close to the equador: roseau
# City close to the equador: port hedland
# City close to the equador: bahia de caraquez
# City not close to the equador: {city}
# City close to the equador: quincy
# City close to the equador: san pedro
# City close to the equador: te anau
# City close to the equador: nuevo laredo
# City close to the equador: ngunguru
# City close to the equador: barabai
# City close to the equador: eydhafushi
# City close to the equador: hafizabad
# City close to the equador: ostersund
# City close to the equador: korla
# City close to the equador: faya
# City not close to the equador: {city}
# City close to the equador: lakes entrance
# City close to the equador: saint-augustin
# City close to the equador: necochea
# City close to the equador: neustrelitz
# City close to the equador: sigli
# City close to the equador: sesheke
# City close to the equador: mutoko
# City close to the equador: cascais
# City close to the equador: okhotsk
# City close to the equador: norman wells
# City not close to the equador: {city}
# City close to the equador: redlands
# City not close to the equador: {city}
# City close to the equador: wuwei
# City close to the equador: klyuchi
# City not close to the equador: {city}
# City close to the equador: taveta
# City close to the equador: kilis
# City close to the equador: nalus
# City close to the equador: bonfim
# City close to the equador: port macquarie
# City not close to the equador: {city}
# City close to the equador: perbaungan

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Dictionary 
weather_cities = {
    "City" : city_name, 
    "Country" : country,
    "Cloudiness" : cloudiness,
    "Humidity" : humidity,
    "Lat" : lat,
    "Lng" : lng,
    "Max Temperature" : max_temp,
    "Wind Speed" : wind_speed
    }
weather_cities_d = pd.DataFrame(weather_cities)
weather_cities_d.head()
# Out:
#              City Country  Cloudiness  Humidity      Lat       Lng  \
# 0   Berdigestyakh      RU         100        94  62.0989  126.6992
# 1  Guerrero Negro      MX         100        51  27.9769 -114.0611
# 2   San Francisco      US           0        53  37.7749 -122.4194
# 3           Dewas      IN           0        33  22.9667   76.0667
# 4        Ust-Nera      RU         100        91  64.5667  143.2000
#
#    Max Temperature  Wind Speed
# 0            -6.72        5.23
# 1            63.79        2.26
# 2            59.14        1.01
# 3            60.94        6.71
# 4           -17.19        1.95

# %%
# Save Data to csv

weather_cities_d.to_csv(output_data_file)

weather_cities_d.head(10)
# Out:
#              City Country  Cloudiness  Humidity      Lat       Lng  \
# 0   Berdigestyakh      RU         100        94  62.0989  126.6992
# 1  Guerrero Negro      MX         100        51  27.9769 -114.0611
# 2   San Francisco      US           0        53  37.7749 -122.4194
# 3           Dewas      IN           0        33  22.9667   76.0667
# 4        Ust-Nera      RU         100        91  64.5667  143.2000
# 5           Kapaa      US           0        65  22.0752 -159.3190
# 6     Fort Nelson      CA         100        93  58.8053 -122.7002
# 7       Busselton      AU           0        29 -33.6500  115.3333
# 8          Castro      BR         100        99 -24.7911  -50.0119
# 9    Punta Arenas      CL           0        87 -53.1500  -70.9167
#
#    Max Temperature  Wind Speed
# 0            -6.72        5.23
# 1            63.79        2.26
# 2            59.14        1.01
# 3            60.94        6.71
# 4           -17.19        1.95
# 5            73.72        0.00
# 6            20.79        4.61
# 7            88.09        4.38
# 8            65.10        6.53
# 9            42.91        3.44

# %% [markdown]
# ## There aren't cities with humidity > 100%. Please see the data frames below:
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Filter all rows for which cities have humidity over 100%.
weather_cities_d.loc[weather_cities_d['Humidity'] >= 100,:]
# Out:
#                 City Country  Cloudiness  Humidity      Lat       Lng  \
# 72            Cairns      AU          75       100 -16.9167  145.7667
# 177       Inowrocław      PL          25       100  52.7989   18.2639
# 196      Port-Gentil      GA          20       100  -0.7193    8.7815
# 203            Natal      BR          75       100  -5.7950  -35.2094
# 301            Ulkan      RU         100       100  57.2430  107.3223
# 325           Baykit      RU         100       100  61.6700   96.3700
# 335            Ghedi      IT         100       100  45.4011   10.2793
# 374             Umeå      SE          40       100  63.8284   20.2597
# 387         Chunskiy      RU          69       100  56.0815   99.6342
# 398        Berezniki      RU          99       100  59.4152   56.8124
# 410  Arraial do Cabo      BR          40       100 -22.9661  -42.0278
# 442        Mount Isa      AU          75       100 -20.7333  139.5000
# 502         Coos Bay      US           0       100  43.3665 -124.2179
#
#      Max Temperature  Wind Speed
# 72             82.06        3.44
# 177            33.12        1.99
# 196            76.96        0.00
# 203            75.85        1.14
# 301           -22.31        2.06
# 325           -12.10        1.86
# 335            43.05        3.44
# 374            29.91        4.61
# 387           -14.12        1.48
# 398            -2.33        3.02
# 410            73.36        0.00
# 442            74.97       10.36
# 502            45.99        0.00

# %%
#  Get the indices of cities that have humidity over 100%.
mean_agg = weather_cities_d.groupby(["City"]).agg(["mean"])
mean_agg_d = pd.DataFrame(equetions_agg)

mean_agg_d.head()
# Out:
#                    Cloudiness Humidity      Lat       Lng Max Temperature  \
#                          mean     mean     mean      mean            mean
# City Name
# Acapulco de Juárez        0.0       78  16.8634  -99.8901           76.78
# Adrar                    78.0       19  20.5022  -10.0711           62.85
# Ahipara                 100.0       55 -35.1667  173.1667           73.47
# Airai                   100.0       87  -8.9266  125.4092           62.82
# Ajdabiya                 12.0       67  30.7554   20.2263           53.38
#
#                    Wind Speed
#                          mean
# City Name
# Acapulco de Juárez       3.80
# Adrar                    3.96
# Ahipara                  5.75
# Airai                    3.33
# Ajdabiya                 9.98

# %%
max_tem_agg = weather_cities_d.groupby(["Max Temperature"]).agg(["max"])
max_tem_agg_d = pd.DataFrame(max_tem_agg)

max_tem_agg_d.head()
# Out:
#                        City Country Cloudiness Humidity      Lat       Lng  \
#                         max     max        max      max      max       max
# Max Temperature
# -40.56             Khandyga      RU         90       99  62.6667  135.6000
# -33.18             Cherskiy      RU         50       98  68.7500  161.3000
# -31.18           Chokurdakh      RU         81       96  70.6333  147.9167
# -26.09           Deputatsky      RU         99       99  69.3000  139.9000
# -24.05                Pevek      RU         28       99  69.7008  170.3133
#
#                 Wind Speed
#                        max
# Max Temperature
# -40.56                2.68
# -33.18                2.82
# -31.18                1.97
# -26.09                2.46
# -24.05                1.86

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type

x_values = weather_cities_d["Lat"]
y_values = weather_cities_d["Max Temperature"]
plt.scatter(x_values,y_values)
plt.title("Temperature in Cities that are close to the equador\
          1-29-2022, 11:40pm")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()

# Save the figure
plt.savefig("Lat_vs_Temp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type

x_values = weather_cities_d["Lat"]
y_values = weather_cities_d["Humidity"]
plt.scatter(x_values,y_values)
plt.title("Humidity in Cities that are close to the equador\
          1-29-2022, 11:43pm")
plt.xlabel('Latitude')
plt.ylabel("Humidity")
plt.show()

# Save the figure
plt.savefig("Lat_vs_Humid.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type

x_values = weather_cities_d["Lat"]
y_values = weather_cities_d["Cloudiness"]
plt.scatter(x_values,y_values)
plt.title("Cloudiness in Cities that are close to the equador\
          1-29-2022, 11:45pm")
plt.xlabel('Latitude')
plt.ylabel("Cloudiness")
plt.show()

# Save the figure
plt.savefig("Lat_vs_Cloudi.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type

x_values = weather_cities_d["Lat"]
y_values = weather_cities_d["Wind Speed"]
plt.scatter(x_values,y_values)
plt.title("Wind Speed in Cities that are close to the equador\
          1-29-2022, 11:48pm")
plt.xlabel('Latitude')
plt.ylabel("Wind Speed")
plt.show()

# Save the figure
plt.savefig("Lat_vs_WindSpeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude

y_values = weather_cities_d["Lat"]
x_values = weather_cities_d["Max Temperature"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Temperature')
plt.ylabel('Latitud')
plt.title("Temperature vs. latitude 1-30-2022")

# Print r square value
print(f"R squared: {rvalue**2}")


# Save the figure
plt.savefig("Reg_Lat_vs_Temp.png")
# Out:
# R squared: 0.6247288776476845

# %%
# Northern Hemisphere Data Frames

north_hem = weather_cities_d.loc[weather_cities_d["Lat"] >= 0]
north_hem_df= pd.DataFrame(north_hem)

north_hem_df.head()
# Out:
#              City Country  Cloudiness  Humidity      Lat       Lng  \
# 0   Berdigestyakh      RU         100        94  62.0989  126.6992
# 1  Guerrero Negro      MX         100        51  27.9769 -114.0611
# 2   San Francisco      US           0        53  37.7749 -122.4194
# 3           Dewas      IN           0        33  22.9667   76.0667
# 4        Ust-Nera      RU         100        91  64.5667  143.2000
#
#    Max Temperature  Wind Speed
# 0            -6.72        5.23
# 1            63.79        2.26
# 2            59.14        1.01
# 3            60.94        6.71
# 4           -17.19        1.95

# %%
# Southern Hemisphere Data Frames

south_hem = weather_cities_d.loc[weather_cities_d["Lat"] < 0]
south_hem_df= pd.DataFrame(south_hem)

south_hem_df.head()
# Out:
#             City Country  Cloudiness  Humidity      Lat       Lng  \
# 7      Busselton      AU           0        29 -33.6500  115.3333
# 8         Castro      BR         100        99 -24.7911  -50.0119
# 9   Punta Arenas      CL           0        87 -53.1500  -70.9167
# 13         Rundu      NA         100        90 -17.9333   19.7667
# 15       Ushuaia      AR          97        94 -54.8000  -68.3000
#
#     Max Temperature  Wind Speed
# 7             88.09        4.38
# 8             65.10        6.53
# 9             42.91        3.44
# 13            66.31        5.32
# 15            46.06        3.98

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_values = north_hem_df["Lat"]
x_values = north_hem_df["Max Temperature"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Temperature')
plt.ylabel('Latitud')
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression 1-30-2022")

# Print r square value
print(f"R squared: {rvalue**2}")


# Save the figure
plt.savefig("Reg_North_Max_t_vs_Lat.png")
# Out:
# R squared: 0.7297089299315068

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_values = south_hem_df["Lat"]
x_values = south_hem_df["Max Temperature"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Temperature')
plt.ylabel('Latitud')
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression 1-30-2022")

# Print r square value
print(f"R squared: {rvalue**2}")


# Save the figure
plt.savefig("Reg_South_Max_t_vs_Lat.png")
# Out:
# R squared: 0.15061425058892716

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hem_df["Humidity"]
y_values = north_hem_df["Lat"]


# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Humidity')
plt.ylabel('Latitud')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Print r square value
print(f"R squared: {rvalue**2}")


# Save the figure
plt.savefig("Reg_North_Humid_vs_Lat.png")
# Out:
# R squared: 0.1980385092263165

# %%
north_hem_df["Humidity"].mean()
# Out:
# 73.3925

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_values = south_hem_df["Lat"]
x_values = south_hem_df["Humidity"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel("Humidity")
plt.ylabel('Latitud')
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression 1-30-2022")

# Print r square value
print(f"R squared: {rvalue**2}")


# Save the figure
plt.savefig("Reg_South_Humid_vs_Lat.png")
# Out:
# R squared: 0.14334065826535236

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hem_df["Cloudiness"]
y_values = north_hem_df["Lat"]


# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel("Cloudiness")
plt.ylabel('Latitud')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression 1-30-2022")

# Print r square value
print(f"R squared: {rvalue**2}")


# Save the figure
plt.savefig("Reg_North_Cloudi_vs_Lat.png")
# Out:
# R squared: 0.07714890332358612

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_values = south_hem_df["Lat"]
x_values = south_hem_df["Cloudiness"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Cloudiness')
plt.ylabel('Latitud')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression 1-30-2022")

# Print r square value
print(f"R squared: {rvalue**2}")


# Save the figure
plt.savefig("Reg_South_Cloudi_vs_Lat.png")
# Out:
# R squared: 0.1589431814803509

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = north_hem_df["Lat"]
x_values = north_hem_df["Wind Speed"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Temperature')
plt.ylabel('Latitud')
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression 1-30-2022")

# Print r square value
print(f"R squared: {rvalue**2}")


# Save the figure
plt.savefig("Reg_North_W_Speed_vs_Lat.png")
# Out:
# R squared: 0.042774822471216147

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = south_hem_df["Lat"]
x_values = south_hem_df["Wind Speed"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel("Wind Speed")
plt.ylabel('Latitud')
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression 1-30-2022")

# Print r square value
print(f"R squared: {rvalue**2}")


# Save the figure
plt.savefig("Reg_South_W_Speed_vs_Lat.png")
# Out:
# R squared: 0.038227131140880666
